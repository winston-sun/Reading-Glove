# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
input = np.array([])

# %%
height = 90 # Height of desired img 
width = 90 # Widht of desired img

# %%
image = np.reshape(input, (height, width))
image.shape
# Out:
# (90, 90)

# %%
plt.imshow(image, cmap='gray')
